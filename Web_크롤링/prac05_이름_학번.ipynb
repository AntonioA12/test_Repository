# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
display(HTML("<style>.input_area pre {font-family: Consolas; font-size: 15pt; line-height: 140%;}</style>"))
display(HTML("<style>.output_area pre {font-family: Consolas; font-size: 15pt; line-height: 140%;}</style>"))
# Out:
# <style>.container { width:95% !important; }</style>
# <style>.input_area pre {font-family: Consolas; font-size: 15pt; line-height: 140%;}</style>
# <style>.output_area pre {font-family: Consolas; font-size: 15pt; line-height: 140%;}</style>

# %% [markdown]
# # 제출 방법
# 1. 파일 이름에서 '학번'을 자신의 학번으로, '이름'을 자신의 이름으로 고치시오.

# %% [markdown]
# # 문제 1
# 구글(www.google.com) 에서 로고를 현재 디렉토리에 google_logo.png 파일로 저장하시오.

# %%
import requests as rq
from bs4 import BeautifulSoup
from urllib.request import urlretrieve
from urllib.parse import urljoin
from IPython.display import Image



# 아래는 수정하지 마시오.
print(img_url)
display(Image(filename='google_logo.png'))
# Out:
# <img alt="Google" height="92" id="hplogo" src="/images/branding/googlelogo/1x/googlelogo_white_background_color_272x92dp.png" style="padding:28px 0 14px" width="272"/>
# https://www.google.com/images/branding/googlelogo/1x/googlelogo_white_background_color_272x92dp.png

# %% [markdown]
# # 문제 2
# http://www.pythonscraping.com/pages/page3.html
#
# 위 쇼핑몰에서 상품의 이미지들을 모두 저장하시오.
#
# 주의)
#
# 1. 로고는 저장하지 마시오.
#
# 2. 그림 파일의 url을 출력하시오.
#
# 3. urljoin 을 이용하시오.
#
# 4. 저장할 파일이름을 추출하여 파일이름 그대로 내 컴퓨터에 저장하시오.
#
# ***실행결과***
# ```
# img1.jpg http://www.pythonscraping.com/img/gifts/img1.jpg
# img2.jpg http://www.pythonscraping.com/img/gifts/img2.jpg
# img3.jpg http://www.pythonscraping.com/img/gifts/img3.jpg
# img4.jpg http://www.pythonscraping.com/img/gifts/img4.jpg
# img6.jpg http://www.pythonscraping.com/img/gifts/img6.jpg
# ```

# %%
from bs4 import BeautifulSoup
from urllib.request import urlretrieve
from urllib.parse import urljoin
from urllib.parse import quote
import requests as rq
import time
import os
# Out:
# <img src="../img/gifts/logo.jpg" style="float:left;"/>
# ../img/gifts/logo.jpg
# http://www.pythonscraping.com/img/gifts/logo.jpg
