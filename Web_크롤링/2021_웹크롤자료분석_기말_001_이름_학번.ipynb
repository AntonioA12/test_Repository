# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
display(HTML("<style>.input_area pre {font-family: Consolas; font-size: 15pt; line-height: 140%; font-weight: bold}</style>"))
display(HTML("<style>.output_area pre {font-family: Consolas; font-size: 15pt; line-height: 140%;}</style>"))
# Out:
# <style>.container { width:95% !important; }</style>
# <style>.input_area pre {font-family: Consolas; font-size: 15pt; line-height: 140%; font-weight: bold}</style>
# <style>.output_area pre {font-family: Consolas; font-size: 15pt; line-height: 140%;}</style>

# %% [markdown]
# # 웹크롤자료분석 001반 기말고사 6월 15일
# - 주의 사항
#     1. 항상 두 손이 캠이나 휴대폰이 촬영할 수 있는 곳(키보드위, 마우스위, 얼굴)에 있도록 하시오.
#     1. 질문이 있으면 DM을 보내거나 마이크를 이용하시오.
#     1. 종료시간
#         - 11시 15분
#     1. 부분점수는 없습니다.
#     1. Closed book
#         - 부정행위시 F 처리
#     1. 수시로 저장하세요.
#     1. 셀을 실행시켰을 때, 멈추지 않는다면, 주피터노트북 메뉴에 있는 정지버튼을 누르거나 Kernel 메뉴에서 restart를 누르세요.
#         - 그래도 동작하지 않는 경우에는 주피터노트북을 다시 시작하세요.
# - 제출 방법
#     1. 파일 이름에서 '학번'을 자신의 학번으로, '이름'을 자신의 이름으로 고치시오.
#     1. 제출하고 `'제출'`이라고 교수에게 DM을 보내시오.
#     1. 제출하면 컴퓨터와 휴대폰에서 회의를 종료하시오.
#     1. LMS에 주피터노트북 파일(.ipynb)을 제출하세요.
#         1. LMS 사용이 불가능한 경우, 이메일로 아래 주소로 제출 하세요.
#             - ydhwang@suwon.ac.kr
#             - 메일제목: `[웹크롤자료분석] <이름> <본인학번>`

# %% [markdown]
# # 반드시 아래 셀을 실행 시키고, 결과를 복사하여 교수에게 DM으로 보내세요.

# %%
import socket
import datetime
hostname = socket.gethostname()
ip_address = socket.gethostbyname(hostname)
print(f"Hostname: {hostname}")
print(f"IP Address: {ip_address}")
print(f"{datetime.datetime.now()}")

# %% [markdown]
# # ----- 주관식 문제 -----
# - 문제당 5점

# %% [markdown]
# ## 문제 1
#
# CSS 선택자에서,
#
# A태그와 B태그는 조상-후손 관계이고, 이런 관계에 있는 B 태그를 선택하는 선택자를 쓰시오.

# %%
print("")

# %% [markdown]
# ## 문제 2
#
# HTML 폼 태그에서 폼 요청을 처리할 서버 파일은 이 태그속성으로 지정한다. 이 태그속성이 이름은 무엇인가?

# %%
print("")

# %% [markdown]
# ## 문제 3
#
# 이것은 웹사이트 접속시 접속자의 개인장치에 다운로드 되고 브라우저에 저장되는 작은 텍스트 파일이다.
#
# 웹사이트는 이것을 통해 접속자의 장치를 인식하고, 접속자의 설정과 과거 이용내역에 대한 일부 데이터를 저장한다.
#
# 이것은 무엇인가?

# %%
print("")

# %% [markdown]
# ## 문제 4
#
# 이것은 인터넷 사용자(희생자)가 자신의 의지와는 무관하게 공격자가 의도한 행위(수정, 삭제, 등록 등)를 특정 웹사이트에 요청하게 만드는 해킹 공격이다. 이것을 무엇이라고 하는가?
#
# 영어 약자로 작성하시오.

# %%
print("")

# %% [markdown]
# ## 문제 5
#
# 이것은 `Representational State Transfer API` 라는 용어의 약자로 HTTP프로토콜을 통해 서버가 제공하는 기능을 사용할 수 있게 해주는 API다. 이것은 무엇인가?

# %%
print("")

# %% [markdown]
# ## 문제 6
#
# 웹페이지를 구성하는 3가지 중요한 요소를 쓰시오.
#
# 각각 웹페이지의 구조, 스타일, 기능을 담당한다.

# %%
print(' , , ')

# %% [markdown]
# # ----- O, X 문제 -----
# - 맞추면 6점, 틀리면 0점, 비워두면 3점
# - O 와 X 를 선택하여 출력하세요.

# %% [markdown]
# ## 문제 1
# openpyxl 에서 엑셀파일을 `book`이라고 하고, `book` 하나는 여러 개의 `sheet` 를 가질 수 있다.

# %%
print("")

# %% [markdown]
# ## 문제 2
#
# 로그인 과정에서 보안을 강화 하기 위해,
#
# 세션ID가 만들어지면 서버에서만 보관되고, 클라이언트는 그 값을 알 수 없다.

# %%
print("")

# %% [markdown]
# ## 문제 3
#
# 로그인 보완과 관련하여, 어떤 사이트에서 요청이 왔는지 확인하는 것을 `user-agent 확인` 이라고 한다.

# %%
print("")

# %% [markdown]
# ## 문제 4
#
# HTTP GET 요청 방식은 로그인에는 사용 할 수 없다.

# %%
print("")

# %% [markdown]
# ## 문제 5
#
# Javascript는 프로그래밍이 가능한 언어이다.

# %%
print("")

# %% [markdown]
# ## 문제 6
#
# OpenAPI는 데스크탑의 웹브라우저에서는 사용가능하지만, 모바일 기기에서는 사용할 수 없다.

# %%
print("")

# %% [markdown]
# # ----- 코딩 문제 -----
# - 문제당 8점

# %% [markdown]
# ## 문제 1
#
# BeautifulSoup 과 선택자를 이용하여,
#
# 주어진 html 에서 `id`태그 속성값이 `toy`인 모든 태그의 텍스트를 한 줄에 하나씩 출력하시오.
#
# ***결과***
# ```
# 2
# 4
# ```

# %%
from bs4 import BeautifulSoup

html = """
<html>
    <body>
        <div id='up'>
            <a class='left right'>1</a>
            <a class='ok' id='toy'>2</a>
        </div>
        <div id='down'>
            <a class='left right'>3</a>
            <a class='ok left' id='toy'>4</a>
            <a class='ok'>5</a>
            <span><a class='left box'>6</a></span>
        </div>
    </body>
</html>
"""

# %% [markdown]
# ## 문제 2
#
# BeautifulSoup 과 선택자를 이용하여,
#
# 주어진 html 에서 `p`태그를 부모로 가지고, `class` 태그속성값이 `left`인 모든 `a`태그를 선택자를 이용해서 선택하시오.
# 선택한 태그들의 text 값을 아래와 같이 출력하시오.
#
# ***결과***
# ```
# 1
# 4
# ```

# %%
from bs4 import BeautifulSoup

html = """
<html>
    <body>
        <div id='up'>
            <p><a class='left right'>1</a></p>
            <a class='ok left'>2</a>
        </div>
        <div id='down'>
            <p><a class='right'>3</a></p>
            <p><a class='ok left'>4</a></p>
            <a class='ok'>5</a>
            <span><a class='left box'>6</a></span>
        </div>
    </body>
</html>
"""

# %% [markdown]
# ## 문제 3
#
# https://kin.naver.com/search/list.nhn?query=%EC%9B%B9%EA%B0%9C%EB%B0%9C&section=kin&sort=vcount
#
# BeautifulSoup 과 선택자를 이용하여,
#
# 위 사이트에서 보여지는 모든 지식인 질문들에서, 제목과 답변수를 크롤링하여 아래와 같이 출력하시오.
#
# ***결과***
# ```
# 1: 빅데이터전문가 온라인 취득? [답변수 6]
# 2: 양성평등 사례 [답변수 2]
# 3: 모바일홈페이지제작을 맡기려고해요! [답변수 1]
# 4: 강남컴퓨터학원 파이썬, 자바 프로그래밍 [답변수 1]
# 5: 부산 it학원 (자바 웹개발) [답변수 1]
# 6: 코딩학원 선택이 중요하다고 하는데ㅠㅠ [답변수 1]
# 7: 서울 IT학원 국비지원되는곳 [답변수 1]
# 8: 부산it학원 국비지원되는곳 [답변수 2]
# 9: 웹개발 자바교육 국비지원 가능한곳 [답변수 1]
# 10: 모바일홈페이지제작, 기업홈페이지 같이...  [답변수 1]
# ```

# %%
import requests as rq
from bs4 import BeautifulSoup

url = 'https://kin.naver.com/search/list.nhn?query=%EC%9B%B9%EA%B0%9C%EB%B0%9C&section=kin&sort=vcount'

# %% [markdown]
# ## 문제 4
#
# https://kr.indeed.com/jobs?q=
#
# - 위의 주소를 이용하여 특정 키워드로 검색한 결과를 크롤링하시오.
#     1. indeed_crawling() 함수를 참고하여 indeed_crawling_csv() 함수를 작성하시오.
#     1. 키워드로 검색된 첫번째 페이지에 있는 채용공고 4개를 크롤링하여
#     1. 채용공고의 `날짜`, `위치`, `회사`, `제목`, `요약` 을 추출하시오.
#     1. 추출한 결과에 번호를 붙여서 리스트 행태로 화면에 출력하시오.
#     1. CSV 파일로 결과를 저장하시오.
#         1. 저장할 파일이름은 현재 디릭토리에 `자신의이름_학번.csv` 로 만드시오.
#             - 예) 홍길동_123456.csv
#
#
# - 파라미터
#     - keyword: 검색하고 싶은 문자열
#     - return: 없음
#
# - 참고
#     - open, encoding, newline, utf-8, .writer(), .writerow(), .close()
#
#
# 결과는 서버상황에 따라 달라질 수 있음
#
# 주피터노트북으로 저장된 csv 파일을 열었을때 아래와 비슷한 형태가 나와야 함.
# ![image.png](attachment:image.png)
#
# ***결과***
# ```
# [1, 'LG전자', '서울 영등포구', 'Data Scientist', '적화/Scoring 등 다양한 분석 모델링 수행 및 결과 평가 2. 트렌드 센싱을 위한 데이터 리딩 - 데이터 \n크롤링, 분석, 분석의 시각화 등을 통한 시장 인사이트 도출 기타 역량 - 상품기획 / 마케팅 및 유관부서 실무경...']
# [2, 'Nexon', '성남 분당구', '데이터 분석 / 모델링', '유저의 특징을 추론하여 데이터로 구체화 1.베이지안 추론 2.패턴인식/머신러닝 3.네트워크 모델링 4.\n크롤링/스크래핑 자동화 -게임이상탐지 : 게임내 발생 할 수 있는 다양한 이상상황 (버그 / 장애 / 유저의 어뷰...']
# [3, '시니어앤파트너즈', '서울 서초구', '[서초구] Node 서버 개발자 (경력)', '개발자간 의사소통이 원활한 분 - python selenium으로 웹 \n크롤링을 해본 분 - socket 통신 경험자 [서초구] Node 서버 개발자... python selenium으로 웹 \n크롤링을 해본 분- socket 통신...']
# [4, 'Nexon', '성남 분당구', '콘텐츠서비스개발- 데이터엔지니어', '주요업무] - 클라우드 기반 시스템 구축 및 운영(AWS) - 추천 시스템 운영 및 모니터링 - 웹 \n크롤링을 활용한 데이터 수집 - 데이터 분석 환경 구축 및 운영 - 서비스 자동화 업무 지원자격 - 경력제한 없음...']
# ```

# %%
import requests as rq
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from urllib.parse import quote
import csv

# 아래 함수를 참고하여 indeed_crawling_csv() 함수를 작성하시오.
def indeed_crawling(keyword):
    print(f"Indeed 검색: {keyword}")
    url_encoded_keyword = quote(keyword)
    url = f"https://kr.indeed.com/jobs?q={url_encoded_keyword}"
    res = rq.get(url)
    soup = BeautifulSoup(res.text, 'lxml')
    tags = soup.select('.jobsearch-SerpJobCard')

    for i, t in enumerate(tags, 1):
        title = t.select_one('.jobtitle').get('title').strip()
        company = t.select_one('.company').text.strip()
        location = t.select_one('.location').text.strip()
        print(f"{i} - [{location}][{company}]: {title}")


def indeed_crawling_csv(keyword):
    pass

# 아래는 수정하지 마시오.
indeed_crawling_csv("크롤링")

# %% [markdown]
# ## 문제5
#
# http://dowellcomputer.com/member/memberLoginForm.jsp
#
# - 세션을 이용하여 위의 사이트에 로그인하는 함수 login_fun() 를 완성하시오.
#     - 로그인 ID와 비밀번호
#         - ID: `dsdsds`
#         - 비밀번호: `dsdsds`
#
# - login_fun() 파라미터:
#     - s: 세션 객채
#     - return: 없음
#
# ***결과***
# ```
# Email: dsdsds@dsdsds.com
# ```

# %%
import requests as rq
from bs4 import BeautifulSoup


def login_fun(s):
    pass

## 아래는 수정하지 마시오.
with rq.Session() as s:
    login_fun(s)
    
    test_url = "http://dowellcomputer.com/member/memberUpdateForm.jsp?ID=dsdsds"
    user_info_res = s.get(test_url)
    user_info_soup = BeautifulSoup(user_info_res.text, 'lxml')
    email = user_info_soup.select_one('[name=memberEmail]').get('value')
    print(f"Email: {email}")

# %% [markdown]
# ## 문제 6
#
# - 아래 과정을 `웹드라이버`를 이용하여 수행하는 프로그램을 작성하시오.
#     - 구글 홈페이지에 접속한다.(https://www.google.com)
#     - 구글 검색 입력 창에 `휴양지`를 입력한다.
#     - `Google 검색` 버튼을 클릭하는 이벤트를 발생시킨다.
#     - 브라우져 화면을 스크린샷을 찍는다.
#         - 저장할 그림 파일 이름은 `이름_학번.png`로 한다.
#             - 예) 홍길동_123456.png
#     - 브라우져를 종료한다.
#
# - 참고
#     - find_element_by_css_selector, save_screenshot, send_keys, click, close
#
# - 주의)
#     - 서버 상황에 따라 출력결과는 실시간으로 달라질 수 있음
#
# ***결과***
#
# 아래와 그림 유사한 스크린샷이 저장되어야 함
# ![image.png](attachment:image.png)

# %%
import time
from bs4 import BeautifulSoup
from selenium import webdriver

target_url = 'https://www.google.com'

driver = webdriver.Chrome('./chromedriver.exe')

## 구글 접속
pass
time.sleep(4)


## `휴양지` 입력
pass
time.sleep(4)


## 'Google 검색' 버튼 클릭
pass
time.sleep(4)

## 스크린샷 저장
pass
time.sleep(1)

driver.close()

# %% [markdown]
# ## 문제 7
#
# https://developers.naver.com/docs/serviceapi/search/movie/movie.md#%EC%98%81%ED%99%94
#
# - 위 사이트를 참고하여, 검색어를 이용하여 영화제목 검색하여 출력하는 함수를 완성하시오.
# - 검색 조건:
#     - 영화장르: 드라마
#     - 검색결과 출력건수: 5개
#
# - API 인증키 정보
#     - Client-ID: `krhM6JH6sLvevhNHpMpd`
#     - Client-Secret: `6a0hkVlPRu`
#
# - 파라미터:
#     - search_text: 검색하고 싶은 문자열
#     - return: 없음
#
#
#
# 출력결과는 서버상황에 따라 일부 달라질 수 있음
#
# ***출력***
#
# ```
# 1 럭키택배 : 영원한 <b>사랑</b>
# 2 내일도 우린 <b>사랑</b>하고 있을까
# 3 <b>사랑</b>하고 <b>사랑</b>받고 차고 차이고
# 4 <b>사랑</b> 뒤의 <b>사랑</b>
# 5 우리는 <b>사랑</b> 아니면 여행이겠지
#
# 1 <b>정말</b> 먼 곳
# 2 우리 <b>정말</b> 헤어졌을까
# 3 괜찮아! <b>정말</b>?
# 4 잘났어 <b>정말</b>
# 5 <b>정말</b> 간절히 기원하면
# ```

# %%
import requests as rq
from urllib.parse import urlencode

# 이 함수에 미리 작성된 코드를 참고하되, 수정 할 수 있습니다.
def movie_search(search_text):
    client_id = 'krhM6JH6sLvevhNHpMpd'
    client_secret = '6a0hkVlPRu'
    
    api_url = None

    data = None

    headers = None

    request_url = None
    res = None
    res_data = res.json()
    
    if res.status_code == 200:
        for index, item in enumerate(res_data['items']):
            print (index + 1, item['title'])
    else:
        print("Error Code:", res.status_code)
        print(res_data)

        
# 아래는 수정하지 마시오.
movie_search('사랑')
print()
movie_search('정말')

# %% [markdown]
# # 수고하셨습니다.
# # 저장하고 제출하세요.
