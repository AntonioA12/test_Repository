# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # 15016033 안효빈 - 인공지능입문

# %% [markdown]
# (문제) 다음의 프로그램을 작성하여라.
#
# 당신은 Ubar 서비스를 이용하는 개인 자가용 사업자입니다.
#
# 당신은 하루에 총 400분의 시간 동안 Ubar 서비스를 이용하여 승객을 매칭하고 이를 통해 수입을 얻습니다. 탑승 요금은 승객이 탑승하는 시간에 비례하여 받게 되며 1분에 500원을 받는다고 합니다. 탑승 고객은 다음의 조건을 만족하고, 탑승을 마친 후 다음 승객을 매칭하기까지 걸리는 시간은 10분이라고 가정합니다.
#
#
#
# 조건1: 승객별 운행 소요시간은 5분~55분 사이의 난수로 정해집니다.
#
# 조건2: 당신은 소요 시간 5분 ~ 20분 사이의 승객만 매칭해야 합니다.
#
#
#
# 이 경우, 당신은 하루에 Ubar 서비스를 이용하여 총 얼마의 수입을 얻게 되나요?
#
#
#
# (출력문 예제)
#
# 당신은 오늘 하루 동안 총50명의 승객 중 20명의 승객과 매칭하여 10만원의 수익을 얻었습니다.
#
# 오늘 하루 수고하셨습니다.

# %%
from random import *

count = 0 
money = 0 
w_time = 0 # 근무시간 400분 
m_time =10 # 매칭대기시간 10분 

for i in range (1,1000): # 승객 수  
    time = randrange(5,55) # 5분 ~ 50분 소요시간 인 승객 
    if 5<= time <=20: # 10분 ~ 30분 사이의승객만 픽업 
        count += 1 
        money += time * 500
        w_time += time # 총 근무시간 
        print(" {0}번째 손님 픽업! ( 소요시간 {1}분 , 토탈 근무시간 {2} 분 )".format(i , time ,w_time ))
        w_time += m_time # 매칭 시간 10분 + 
            
        if w_time + time > 400: 
            print(' 근무시간 초과 ! 퇴근합시다.')
            break
            
    else : 
        print(" {0} 번째 손님 (소요시간 {1}분) 다른손님을 탐색합니다......".format(i , time))
        
print('=' * 100)        
print(' 당신은 오늘하루 동안 총 {0}명의 승객중 {1} 명의 승객과 매칭하여 {2} 원의 수익을 얻었습니다'.format(i, count,money))
print( ' 오늘 하루 수고하셨습니다.' )

## P.S 일부 가정

# 가정 1. 일한시간(400분)은 손님을 태운시간만 포함한다.
# 가정 2. 마지막손님은 400분이 초과해도 근무한다.
# Out:
#  1번째 손님 픽업! ( 소요시간 6분 , 토탈 근무시간 6 분 )
#  2 번째 손님 (소요시간 23분) 다른손님을 탐색합니다......
#  3 번째 손님 (소요시간 27분) 다른손님을 탐색합니다......
#  4번째 손님 픽업! ( 소요시간 18분 , 토탈 근무시간 34 분 )
#  5 번째 손님 (소요시간 32분) 다른손님을 탐색합니다......
#  6 번째 손님 (소요시간 49분) 다른손님을 탐색합니다......
#  7 번째 손님 (소요시간 33분) 다른손님을 탐색합니다......
#  8 번째 손님 (소요시간 48분) 다른손님을 탐색합니다......
#  9번째 손님 픽업! ( 소요시간 13분 , 토탈 근무시간 57 분 )
#  10 번째 손님 (소요시간 47분) 다른손님을 탐색합니다......
#  11 번째 손님 (소요시간 21분) 다른손님을 탐색합니다......
#  12 번째 손님 (소요시간 34분) 다른손님을 탐색합니다......
#  13번째 손님 픽업! ( 소요시간 18분 , 토탈 근무시간 85 분 )
#  14 번째 손님 (소요시간 34분) 다른손님을 탐색합니다......
#  15번째 손님 픽업! ( 소요시간 20분 , 토탈 근무시간 115 분 )
#  16 번째 손님 (소요시간 33분) 다른손님을 탐색합니다......
#  17번째 손님 픽업! ( 소요시간 20분 , 토탈 근무시간 145 분 )
#  18 번째 손님 (소요시간 33분) 다른손님을 탐색합니다......
#  19번째 손님 픽업! ( 소요시간 5분 , 토탈 근무시간 160 분 )
#  20 번째 손님 (소요시간 25분) 다른손님을 탐색합니다......
#  21번째 손님 픽업! ( 소요시간 10분 , 토탈 근무시간 180 분 )
#  22번째 손님 픽업! ( 소요시간 10분 , 토탈 근무시간 200 분 )
#  23 번째 손님 (소요시간 22분) 다른손님을 탐색합니다......
#  24 번째 손님 (소요시간 45분) 다른손님을 탐색합니다......
#  25 번째 손님 (소요시간 50분) 다른손님을 탐색합니다......
#  26 번째 손님 (소요시간 22분) 다른손님을 탐색합니다......
#  27 번째 손님 (소요시간 50분) 다른손님을 탐색합니다......
#  28 번째 손님 (소요시간 37분) 다른손님을 탐색합니다......
#  29 번째 손님 (소요시간 54분) 다른손님을 탐색합니다......
#  30 번째 손님 (소요시간 45분) 다른손님을 탐색합니다......
#  31 번째 손님 (소요시간 28분) 다른손님을 탐색합니다......
#  32 번째 손님 (소요시간 31분) 다른손님을 탐색합니다......
#  33 번째 손님 (소요시간 52분) 다른손님을 탐색합니다......
#  34번째 손님 픽업! ( 소요시간 9분 , 토탈 근무시간 219 분 )
#  35번째 손님 픽업! ( 소요시간 6분 , 토탈 근무시간 235 분 )
#  36 번째 손님 (소요시간 21분) 다른손님을 탐색합니다......
#  37 번째 손님 (소요시간 24분) 다른손님을 탐색합니다......
#  38 번째 손님 (소요시간 40분) 다른손님을 탐색합니다......
#  39 번째 손님 (소요시간 47분) 다른손님을 탐색합니다......
#  40번째 손님 픽업! ( 소요시간 6분 , 토탈 근무시간 251 분 )
#  41번째 손님 픽업! ( 소요시간 7분 , 토탈 근무시간 268 분 )
#  42 번째 손님 (소요시간 49분) 다른손님을 탐색합니다......
#  43번째 손님 픽업! ( 소요시간 8분 , 토탈 근무시간 286 분 )
#  44 번째 손님 (소요시간 51분) 다른손님을 탐색합니다......
#  45 번째 손님 (소요시간 53분) 다른손님을 탐색합니다......
#  46 번째 손님 (소요시간 24분) 다른손님을 탐색합니다......
#  47 번째 손님 (소요시간 49분) 다른손님을 탐색합니다......
#  48 번째 손님 (소요시간 36분) 다른손님을 탐색합니다......
#  49번째 손님 픽업! ( 소요시간 9분 , 토탈 근무시간 305 분 )
#  50 번째 손님 (소요시간 35분) 다른손님을 탐색합니다......
#  51 번째 손님 (소요시간 42분) 다른손님을 탐색합니다......
#  52번째 손님 픽업! ( 소요시간 8분 , 토탈 근무시간 323 분 )
#  53 번째 손님 (소요시간 21분) 다른손님을 탐색합니다......
#  54 번째 손님 (소요시간 46분) 다른손님을 탐색합니다......
#  55번째 손님 픽업! ( 소요시간 15분 , 토탈 근무시간 348 분 )
#  56 번째 손님 (소요시간 30분) 다른손님을 탐색합니다......
#  57 번째 손님 (소요시간 25분) 다른손님을 탐색합니다......
#  58 번째 손님 (소요시간 42분) 다른손님을 탐색합니다......
#  59 번째 손님 (소요시간 46분) 다른손님을 탐색합니다......
#  60 번째 손님 (소요시간 28분) 다른손님을 탐색합니다......
#  61번째 손님 픽업! ( 소요시간 19분 , 토탈 근무시간 377 분 )
#  근무시간 초과 ! 퇴근합시다.
# ====================================================================================================
#  당신은 오늘하루 동안 총 61명의 승객중 18 명의 승객과 매칭하여 103500 원의 수익을 얻었습니다
#  오늘 하루 수고하셨습니다.
